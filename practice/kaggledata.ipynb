# %%
zz

# %%
import pandas as pd
df = pd.read_csv('piracydataset.csv')
df
# Out:
#       Unnamed: 0   age                   discordid      minecraftid  \
# 0              0  14.0            ProGamer300#3331     ProGamer300
# 1              1  19.0                 @shrey#4934      shrey_jain_
# 2              2  18.0             Skullfaced#8657  Skullfaceddeath
# 3              3  17.0            Op DzGhOsT#8719      DzGHoST1737
# 4              4  15.0                Dwijesh#6020       Dwijesh YT
# ...          ...   ...                         ...              ...
# 1418        1418  17.0                     Savager       Asmitraj11
# 1419        1419  15.0  ( @KAMALTHESUPERBOY #6357)        kamal1112
# 1420        1420  17.0                ATHARVA#9034         SPIDEY_2
# 1421        1421  15.0            GOD_RANVEER#3462      GOD_RANVEER
# 1422        1422  14.0         ToughGamer2121#9555    Prachetan2008
#
#                           client       version
# 0      Computer ( Java Edition )       Cracked
# 1      Computer ( Java Edition )       Cracked
# 2      Computer ( Java Edition )  Paid Version
# 3      Computer ( Java Edition )       Cracked
# 4     Mobile ( bedrock version )  Paid Version
# ...                          ...           ...
# 1418   Computer ( Java Edition )       Cracked
# 1419   Computer ( Java Edition )       Cracked
# 1420   Computer ( Java Edition )       Cracked
# 1421   Computer ( Java Edition )       Cracked
# 1422   Computer ( Java Edition )       Cracked
#
# [1423 rows x 6 columns]

# %%
import pandas as pd
df = pd.read_csv('data2.csv')
df.head()
# Out:
#   mod_name                                                                                                      \
# 0  Just Enough Items (JEI)                       ...
# 1  Mouse Tweaks                                  ...
# 2  AutoRegLib                                    ...
# 3  JourneyMap                                    ...
# 4  AppleSkin                                     ...
#
#   author_name                 downloads           \
# 0   mezz                        124.2M Downloads
# 1   YaLTeR                      88.8M Downloads
# 2   Vazkii                      79.9M Downloads
# 3   techbrew                    106.2M Downloads
# 4   squeek502                   77.7M Downloads
#
#   last_updated                                                                     \
# 0  Updated Aug 5, 2021                           ...
# 1  Updated Jul 24, 2021                          ...
# 2  Updated May 26, 2021                          ...
# 3  Updated Aug 9, 2021                           ...
# 4  Updated Aug 9, 2021                           ...
#
#   description                                                                                                                                                \
# 0  View Items and Recipes                        ...
# 1  Enhances inventory management by adding variou...
# 2  A library to ease menial tasks in mod developm...
# 3  Real-time mapping in-game or your browser as y...
# 4  Adds some useful information about food/hunger...
#
#   page_link                                                                                                      \
# 0  https://www.curseforge.com/minecraft/mc-mods/j...
# 1  https://www.curseforge.com/minecraft/mc-mods/m...
# 2  https://www.curseforge.com/minecraft/mc-mods/a...
# 3  https://www.curseforge.com/minecraft/mc-mods/j...
# 4  https://www.curseforge.com/minecraft/mc-mods/a...
#
#   author_link                                                     page_number
# 0  https://www.curseforge.com/members/mezz       ...                      1.0
# 1  https://www.curseforge.com/members/yalter     ...                      1.0
# 2  https://www.curseforge.com/members/vazkii     ...                      1.0
# 3  https://www.curseforge.com/members/techbrew   ...                      1.0
# 4  https://www.curseforge.com/members/squeek502  ...                      1.0

# %%
df.columns = [col.replace(' ', '') for col in df.columns]
df.columns
# Out:
# Index(['mod_name', 'author_name', 'downloads', 'last_updated', 'description',
#        'page_link', 'author_link', 'page_number'],
#       dtype='object')

# %%
import pandas as pd
import re 
from googletrans import Translator # 한국어 번역기

df = pd.read_csv('data2.csv')
pd.set_option('display.max_colwidth', None) # 내용 잘림없이 보기위해
df.columns = [col.replace(' ', '') for col in df.columns] # 공백처리
df['downloads'] = df['downloads'].map(lambda x : re.findall(r'\d+',x)) # 숫자만 처리
df['downloads'] = df['downloads'].map(lambda x : x[0] if x else None)  # 숫자에서 첫번쨰 원소만 , 원소가 없으면 none
df = df[['mod_name','downloads','description']].sort_values(ascending=False,by='downloads')
df_100 = df.head(100)
df_100
# Out:
#                                                                                                          mod_name  \
# 18288  UsefulMisc
# 19162  Menu Library
# 12968  Cursed Mod
# 13275  McDonalds
# 19355  Photosynthite
# ...                                                                                                           ...
# 10201  Rainbow6
# 13354  SugarDesertmod
# 20162  Cheese Mod v 1.4.1
# 21468  Splash Dye
# 19921  Beyond the Grave
#
#       downloads  \
# 18288       999
# 19162       999
# 12968       999
# 13275       998
# 19355       998
# ...         ...
# 10201       985
# 13354       985
# 20162       985
# 21468       985
# 19921       985
#
#                                                                                                                                                    description
# 18288  Adds various building materials and much stronger materials to the game.
# 19162  Browsable Main Menus
# 12968  Things are stalking you ♦ Creepy/Horror/Survival Mod ♦ Forge ♦ 1.16.4 ♦
# 13275  Eine McDonalds Mod
# 19355  Adds 5 New ores with Armor and Tools, and 3 brand new biomes
# ...                                                                                                                                                        ...
# 10201  Play Rainbow6:siege in Minecraft!
# 13354  Sugar!!!!
# 20162  Cheese Mod adds four new types of cheese, along with several other fun things!
# 21468  Craft dye and water bottles into throwable dyes to change the colours of your sheep!
# 19921  Spawn zombies that hold your items when you die!
#
# [100 rows x 3 columns]
